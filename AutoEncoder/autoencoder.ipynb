# %%
import sys
import torch
import numpy as np
from autoencoder import AutoEncoder
import matplotlib.pyplot as plt
sys.path.append("/data/bitt/wzq/wzq/GANs/")
from utils import make_image

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = AutoEncoder().to(device)

# %%
model.load_state_dict(torch.load('best.pt'))

# %%
from torchsummary import summary

# %%
x = sorted(np.random.randn(8))
print(x)
z = []
for i in x:
    for j in x:
        z.append([i, j])
# Out:
# [-1.5929429817008292, -0.9880188315092306, -0.974617881975273, -0.7611216218021446, -0.002065610051232995, 0.002865102411311127, 0.932036088225288, 1.3543329821644867]

# %%
z = np.array(z)

# %%
z = torch.from_numpy(z).float().to(device)

# %%
output = model.decoder(z).view(-1, 1, 28, 28)

# %%
make_image(output)
# Out:
# <PIL.Image.Image image mode=RGB size=242x242 at 0x7F0C2C0A90F0>

# %%
print(z)
# Out:
# tensor([[-1.5929, -1.5929],
#         [-1.5929, -0.9880],
#         [-1.5929, -0.9746],
#         [-1.5929, -0.7611],
#         [-1.5929, -0.0021],
#         [-1.5929,  0.0029],
#         [-1.5929,  0.9320],
#         [-1.5929,  1.3543],
#         [-0.9880, -1.5929],
#         [-0.9880, -0.9880],
#         [-0.9880, -0.9746],
#         [-0.9880, -0.7611],
#         [-0.9880, -0.0021],
#         [-0.9880,  0.0029],
#         [-0.9880,  0.9320],
#         [-0.9880,  1.3543],
#         [-0.9746, -1.5929],
#         [-0.9746, -0.9880],
#         [-0.9746, -0.9746],
#         [-0.9746, -0.7611],
#         [-0.9746, -0.0021],
#         [-0.9746,  0.0029],
#         [-0.9746,  0.9320],
#         [-0.9746,  1.3543],
#         [-0.7611, -1.5929],
#         [-0.7611, -0.9880],
#         [-0.7611, -0.9746],
#         [-0.7611, -0.7611],
#         [-0.7611, -0.0021],
#         [-0.7611,  0.0029],
#         [-0.7611,  0.9320],
#         [-0.7611,  1.3543],
#         [-0.0021, -1.5929],
#         [-0.0021, -0.9880],
#         [-0.0021, -0.9746],
#         [-0.0021, -0.7611],
#         [-0.0021, -0.0021],
#         [-0.0021,  0.0029],
#         [-0.0021,  0.9320],
#         [-0.0021,  1.3543],
#         [ 0.0029, -1.5929],
#         [ 0.0029, -0.9880],
#         [ 0.0029, -0.9746],
#         [ 0.0029, -0.7611],
#         [ 0.0029, -0.0021],
#         [ 0.0029,  0.0029],
#         [ 0.0029,  0.9320],
#         [ 0.0029,  1.3543],
#         [ 0.9320, -1.5929],
#         [ 0.9320, -0.9880],
#         [ 0.9320, -0.9746],
#         [ 0.9320, -0.7611],
#         [ 0.9320, -0.0021],
#         [ 0.9320,  0.0029],
#         [ 0.9320,  0.9320],
#         [ 0.9320,  1.3543],
#         [ 1.3543, -1.5929],
#         [ 1.3543, -0.9880],
#         [ 1.3543, -0.9746],
#         [ 1.3543, -0.7611],
#         [ 1.3543, -0.0021],
#         [ 1.3543,  0.0029],
#         [ 1.3543,  0.9320],
#         [ 1.3543,  1.3543]], device='cuda:0')
